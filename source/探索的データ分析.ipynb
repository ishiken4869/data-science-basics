# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/hotel_reviews.csv')
df.head(3)
# Out:
#    性別  年齢 個人/グループ 旅行の目的  Wifi設備  送迎の便利さ  オンライン予約のしやすさ  ホテルの立地  食事の満足度  \
# 0  女性  50    グループ    学生       4       4             4       4       3
# 1  女性  35      個人  ビジネス       4       5             4       4       1
# 2  女性  22    グループ   その他       1       1             1       4       1
#
#    滞在時の快適さ  チェックイン・アウトの接客  その他のサービス  清潔さ  満足度
# 0        4              4         4    4    4
# 1        1              5         4    1    2
# 2        5              1         3    1    3

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   性別             10000 non-null  object
#  1   年齢             10000 non-null  int64
#  2   個人/グループ        10000 non-null  object
#  3   旅行の目的          10000 non-null  object
#  4   Wifi設備         10000 non-null  int64
#  5   送迎の便利さ         10000 non-null  int64
#  6   オンライン予約のしやすさ   10000 non-null  int64
#  7   ホテルの立地         10000 non-null  int64
#  8   食事の満足度         10000 non-null  int64
#  9   滞在時の快適さ        10000 non-null  int64
#  10  チェックイン・アウトの接客  10000 non-null  int64
#  11  その他のサービス       10000 non-null  int64
#  12  清潔さ            10000 non-null  int64
#  13  満足度            10000 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# 性別               0
# 年齢               0
# 個人/グループ          0
# 旅行の目的            0
# Wifi設備           0
# 送迎の便利さ           0
# オンライン予約のしやすさ     0
# ホテルの立地           0
# 食事の満足度           0
# 滞在時の快適さ          0
# チェックイン・アウトの接客    0
# その他のサービス         0
# 清潔さ              0
# 満足度              0
# dtype: int64

# %%
df['満足度'].mean()
# Out:
# 3.2019

# %%
df['満足度'].mode()
# Out:
# 0    3
# Name: 満足度, dtype: int64

# %%
df['満足度'].median()
# Out:
# 3.0

# %%
df['満足度'].hist()
# Out:
# <Axes: >

# %%
df['満足度'].value_counts()
# Out:
# 3    3566
# 4    3349
# 2    1976
# 5     716
# 1     393
# Name: 満足度, dtype: int64

# %%
type(df['満足度'])
# Out:
# pandas.core.series.Series

# %%
df['満足度'].value_counts(normalize=True)
# Out:
# 3    0.3566
# 4    0.3349
# 2    0.1976
# 5    0.0716
# 1    0.0393
# Name: 満足度, dtype: float64

# %%
# !pip install -q japanize_matplotlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 32.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for japanize_matplotlib (setup.py) ... done

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
x = df['満足度'].value_counts()

plt.title('満足度')
plt.pie(x, labels=x.index, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7efcb2d52d70>,
#   <matplotlib.patches.Wedge at 0x7efcb2d538b0>,
#   <matplotlib.patches.Wedge at 0x7efcb2d51210>,
#   <matplotlib.patches.Wedge at 0x7efcb2d50dc0>,
#   <matplotlib.patches.Wedge at 0x7efcb2ded5a0>],
#  [Text(0.47896165919510963, 0.9902503365417594, '3'),
#   Text(-1.0874649695908434, -0.16558967332773616, '4'),
#   Text(0.27556657701683557, -1.0649239698829325, '2'),
#   Text(0.9797931576630836, -0.500005368167787, '5'),
#   Text(1.0916267015247356, -0.1354663962694288, '1')],
#  [Text(0.2612518141064234, 0.540136547204596, '35.7%'),
#   Text(-0.5931627106859144, -0.09032163999694699, '33.5%'),
#   Text(0.15030904200918302, -0.5808676199361449, '19.8%'),
#   Text(0.534432631452591, -0.27273020081879285, '7.2%'),
#   Text(0.5954327462862193, -0.07389076160150661, '3.9%')])

# %%
x = df['性別'].value_counts()
x
# Out:
# 女性    5031
# 男性    4969
# Name: 性別, dtype: int64

# %%
plt.title('性別')
plt.pie(x, labels=x.index, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7efcb2db80d0>,
#   <matplotlib.patches.Wedge at 0x7efcb2d05360>],
#  [Text(-0.010712585476901137, 1.0999478353596595, '女性'),
#   Text(0.010712482492352002, -1.0999478363626392, '男性')],
#  [Text(-0.005843228441946074, 0.5999715465598141, '50.3%'),
#   Text(0.005843172268555637, -0.599971547106894, '49.7%')])

# %%
x = df['個人/グループ'].value_counts()
x
# Out:
# グループ    6798
# 個人      3202
# Name: 個人/グループ, dtype: int64

# %%
plt.title('個人/グループ')
plt.pie(x, labels=x.index, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7efcb30b46a0>,
#   <matplotlib.patches.Wedge at 0x7efcb3055480>],
#  [Text(-0.5888257246049893, 0.9291309197542668, 'グループ'),
#   Text(0.5888256376134713, -0.929130974884106, '個人')],
#  [Text(-0.3211776679663577, 0.5067986835023273, '68.0%'),
#   Text(0.3211776205164389, -0.5067987135731487, '32.0%')])

# %%
x = df['旅行の目的'].value_counts()
x
# Out:
# 旅行      3041
# 学生      2573
# ビジネス    2078
# 航空関係    1384
# その他      924
# Name: 旅行の目的, dtype: int64

# %%
plt.title('旅行の目的')
plt.pie(x, labels=x.index, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7efcb2dee620>,
#   <matplotlib.patches.Wedge at 0x7efcb30b43d0>,
#   <matplotlib.patches.Wedge at 0x7efcb2ded630>,
#   <matplotlib.patches.Wedge at 0x7efcb2decd90>,
#   <matplotlib.patches.Wedge at 0x7efcb3055b70>],
#  [Text(0.6350478165831612, 0.8981727398741067, '旅行'),
#   Text(-1.0032534173278045, 0.45109043507935564, '学生'),
#   Text(-0.5581598765293582, -0.9478700080879929, 'ビジネス'),
#   Text(0.5800429198322498, -0.9346390806896951, '航空関係'),
#   Text(1.0539791536725418, -0.3148459045687471, 'その他')],
#  [Text(0.34638971813626973, 0.4899124035676945, '30.4%'),
#   Text(-0.5472291367242569, 0.24604932822510306, '25.7%'),
#   Text(-0.30445084174328624, -0.5170200044116324, '20.8%'),
#   Text(0.31638704718122707, -0.5098031349216519, '13.8%'),
#   Text(0.5748977201850227, -0.17173412976477112, '9.2%')])

# %%
df['年齢'].hist()
# Out:
# <Axes: >

# %%
df['年齢'].hist(bins=70)
# Out:
# <Axes: >

# %%
df.describe(include='all')
# Out:
#            性別            年齢 個人/グループ  旅行の目的        Wifi設備        送迎の便利さ  \
# count   10000  10000.000000   10000  10000  10000.000000  10000.000000
# unique      2           NaN       2      5           NaN           NaN
# top        女性           NaN    グループ     旅行           NaN           NaN
# freq     5031           NaN    6798   3041           NaN           NaN
# mean      NaN     39.486800     NaN    NaN      2.814000      3.104400
# std       NaN     15.175528     NaN    NaN      1.248984      1.482404
# min       NaN      7.000000     NaN    NaN      1.000000      0.000000
# 25%       NaN     27.000000     NaN    NaN      2.000000      2.000000
# 50%       NaN     40.000000     NaN    NaN      3.000000      3.000000
# 75%       NaN     51.000000     NaN    NaN      4.000000      4.000000
# max       NaN     80.000000     NaN    NaN      5.000000      5.000000
#
#         オンライン予約のしやすさ        ホテルの立地       食事の満足度       滞在時の快適さ  チェックイン・アウトの接客  \
# count   10000.000000  10000.000000  10000.00000  10000.000000   10000.000000
# unique           NaN           NaN          NaN           NaN            NaN
# top              NaN           NaN          NaN           NaN            NaN
# freq             NaN           NaN          NaN           NaN            NaN
# mean        2.841000      2.989100      3.20040      3.438700       3.293900
# std         1.331201      1.274654      1.32658      1.316441       1.261936
# min         0.000000      1.000000      0.00000      1.000000       1.000000
# 25%         2.000000      2.000000      2.00000      2.000000       2.000000
# 50%         3.000000      3.000000      3.00000      4.000000       3.000000
# 75%         4.000000      4.000000      4.00000      5.000000       4.000000
# max         5.000000      5.000000      5.00000      5.000000       5.000000
#
#             その他のサービス           清潔さ           満足度
# count   10000.000000  10000.000000  10000.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean        3.646200      3.281900      3.201900
# std         1.168829      1.310116      0.967176
# min         1.000000      0.000000      1.000000
# 25%         3.000000      2.000000      3.000000
# 50%         4.000000      3.000000      3.000000
# 75%         5.000000      4.000000      4.000000
# max         5.000000      5.000000      5.000000

# %%
# 可視化のサイズをノートブック上で統一する
plt.rcParams['figure.figsize'] = 10, 6

# %%
df.hist()
plt.tight_layout()

# %%
pd.crosstab(df['満足度'], df['性別'])
# Out:
# 性別     女性    男性
# 満足度
# 1     157   236
# 2     959  1017
# 3    1880  1686
# 4    1692  1657
# 5     343   373

# %%
crosstab = pd.crosstab(df['満足度'], df['性別'])

crosstab.plot.bar()
# Out:
# <Axes: xlabel='満足度'>

# %%
import seaborn as sns

# %%
sns.countplot(x='満足度', hue='性別', data=df)
# Out:
# <Axes: xlabel='満足度', ylabel='count'>

# %%
#満足度 - 個人 / グループ　の関係性
pd.crosstab(df['満足度'], df['個人/グループ'])
# Out:
# 個人/グループ  グループ    個人
# 満足度
# 1         224   169
# 2        1107   869
# 3        2308  1258
# 4        2509   840
# 5         650    66

# %%
sns.countplot(x='満足度', hue='個人/グループ', data=df)
# Out:
# <Axes: xlabel='満足度', ylabel='count'>

# %%
group = df.groupby('個人/グループ')

group.mean()
# Out:
# <ipython-input-44-373034026e7f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group.mean()
#                 年齢    Wifi設備    送迎の便利さ  オンライン予約のしやすさ    ホテルの立地    食事の満足度  \
# 個人/グループ
# グループ     39.887026  2.932627  2.839953      2.997205  3.010444  3.277876
# 個人       38.637102  2.562149  3.665834      2.509369  2.943785  3.035915
#
#           滞在時の快適さ  チェックイン・アウトの接客  その他のサービス       清潔さ       満足度
# 個人/グループ
# グループ     3.560312       3.278758  3.681524  3.362018  3.331568
# 個人       3.180512       3.326046  3.571205  3.111805  2.926608

# %%
group.median()
# Out:
# <ipython-input-45-5f4ff1bcd872>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group.median()
#            年齢  Wifi設備  送迎の便利さ  オンライン予約のしやすさ  ホテルの立地  食事の満足度  滞在時の快適さ  \
# 個人/グループ
# グループ     40.0     3.0     3.0           3.0     3.0     3.0      4.0
# 個人       39.0     3.0     4.0           2.0     3.0     3.0      3.0
#
#          チェックイン・アウトの接客  その他のサービス  清潔さ  満足度
# 個人/グループ
# グループ               3.0       4.0  4.0  3.0
# 個人                 3.0       4.0  3.0  3.0

# %%
# 満足度 - 旅行の目的 の関係性
pd.crosstab(df['満足度'], df['旅行の目的'])
# Out:
# 旅行の目的  その他  ビジネス   学生    旅行  航空関係
# 満足度
# 1       33    73  110   124    53
# 2      176   408  483   634   275
# 3      343   740  946  1047   490
# 4      301   703  848  1025   472
# 5       71   154  186   211    94

# %%
sns.countplot(x='満足度', hue='旅行の目的', data=df)
# Out:
# <Axes: xlabel='満足度', ylabel='count'>

# %%
group = df.groupby('旅行の目的')

group.mean()
# Out:
# <ipython-input-49-979fbd38edfc>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group.mean()
#               年齢    Wifi設備    送迎の便利さ  オンライン予約のしやすさ    ホテルの立地    食事の満足度  \
# 旅行の目的
# その他    39.377706  2.834416  3.081169      2.852814  2.959957  3.147186
# ビジネス   39.779596  2.817613  3.079403      2.820500  2.951396  3.212705
# 学生     39.294209  2.798290  3.157015      2.870968  3.022542  3.221920
# 旅行     39.566919  2.786583  3.065439      2.801710  2.975995  3.184150
# 航空関係   39.302023  2.884393  3.145231      2.894509  3.031792  3.213150
#
#         滞在時の快適さ  チェックイン・アウトの接客  その他のサービス       清潔さ       満足度
# 旅行の目的
# その他    3.462121       3.271645  3.698052  3.234848  3.217532
# ビジネス   3.454764       3.297401  3.663619  3.296920  3.219923
# 学生     3.463272       3.333852  3.652157  3.296152  3.200933
# 旅行     3.412364       3.260112  3.616573  3.278856  3.185794
# 航空関係   3.411127       3.303468  3.639451  3.270954  3.201590

# %%
group.median()
# Out:
# <ipython-input-50-5f4ff1bcd872>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group.median()
#          年齢  Wifi設備  送迎の便利さ  オンライン予約のしやすさ  ホテルの立地  食事の満足度  滞在時の快適さ  \
# 旅行の目的
# その他    39.0     3.0     3.0           3.0     3.0     3.0      4.0
# ビジネス   41.0     3.0     3.0           3.0     3.0     3.0      4.0
# 学生     39.0     3.0     3.0           3.0     3.0     3.0      4.0
# 旅行     40.0     3.0     3.0           3.0     3.0     3.0      4.0
# 航空関係   41.0     3.0     3.0           3.0     3.0     3.0      4.0
#
#        チェックイン・アウトの接客  その他のサービス  清潔さ  満足度
# 旅行の目的
# その他              3.0       4.0  3.0  3.0
# ビジネス             3.0       4.0  3.0  3.0
# 学生               3.0       4.0  3.0  3.0
# 旅行               3.0       4.0  3.0  3.0
# 航空関係             3.0       4.0  3.0  3.0
