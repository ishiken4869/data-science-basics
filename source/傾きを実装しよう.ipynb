# %%
1+1
# Out:
# 2

# %% [markdown]
# ## データのアップロード
# 1. GoogleDriveに直接アップロード
# 2. 適宜データをアップロード

# %%
import numpy as np

# %%
x = np.array([1, 2, 3])
y = np.array([2, 3.0, 6.1])

# %%
x.mean()
# Out:
# 2.0

# %%
y.mean()
# Out:
# 3.6999999999999997

# %%
xc = x - x.mean()

# %%
yc = y - y.mean()

# %%
xc
# Out:
# array([-1.,  0.,  1.])

# %%
xx = xc * xc

# %%
xx.sum()
# Out:
# 2.0

# %%
xy = xc * yc

# %%
xy.sum()
# Out:
# 4.1

# %%
a = xy.sum() / xx.sum()
a
# Out:
# 2.05
